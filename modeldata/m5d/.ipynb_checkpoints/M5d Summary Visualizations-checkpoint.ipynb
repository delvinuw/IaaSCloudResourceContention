# %%
#Math stuff
from numpy.random import seed
from numpy.random import randn
from scipy import stats
import numpy as np
import math  

#Visualization stuff
import seaborn as sns
#sns.set(style="darkgrid")
sns.set(style="whitegrid")
from matplotlib import pyplot as plt

import pandas as pd
import os

#ML stuff
from sklearn import preprocessing

# %%
#check list of files in data 
directory = "./data/summary/dedicated_host/"
print(os.listdir(directory))
# Out:
# ['m5d_pgbench_dedicated_host_11-16-2019.csv-Summary.csv', 'm5d_sysbench_dedicated_host_11-16-2019_us-east-1b - Sheet1.csv-Summary.csv', 'm5d_iperf_dedicated_host_11-17.csv-Summary.csv', 'm5d_y-cruncher_dedicated_host_11-16-2019_us-east-1 - Sheet1.csv-Summary.csv', 'Aggregate_Summary_Dedicated_Host_11-16-2019 - Sheet2.csv']

# %%
#import each summary data
data_name = 'Aggregate_Summary_Dedicated_Host_11-16-2019 - Sheet2.csv'

# %%
#add csvs to data frames
df_agg = pd.read_csv(directory + data_name, header = 0)

# %%
df_agg.head()
# Out:
#             instanceID  setId  tenants  sysbench_wallTime  \
# 0  i-0009b7735dea24732      0       48           9.046352
# 1  i-002f7e27ea3e0bc1c      0       48           9.043485
# 2  i-007e12c9530b8cdea      0       48           9.525164
# 3  i-008e6f72c7403b5d3      0       48           9.041284
# 4  i-00ba7a56c944e5a25      0       48           9.042799
#
#    sysbench_std_wallTime  y_cruncher_wallTime  y_cruncher_std_wallTime  \
# 0               0.006011             6.526652                 0.064484
# 1               0.005964             6.532571                 0.044366
# 2               0.693472             6.523446                 0.064272
# 3               0.004991             6.487584                 0.065375
# 4               0.005881             6.568983                 0.087642
#
#    pgbench_transactions  pgbench_std_transactions         instanceID.1  \
# 0           123377.0000                269.838841  i-0009b7735dea24732
# 1           123286.0000                553.898908  i-002f7e27ea3e0bc1c
# 2           122657.6667                572.732340  i-007e12c9530b8cdea
# 3           123779.6667                193.717148  i-008e6f72c7403b5d3
# 4           123144.0000                246.032518  i-00ba7a56c944e5a25
#
#    iperf_bandwidthUpload  iperf_bandwitdhDownload  iperf_total  iperf_stdUp  \
# 0                  612.8                    566.3       1179.1   253.291575
# 1                  518.3                    556.9       1075.2   188.317138
# 2                  371.3                    486.5        857.8   143.431013
# 3                  594.9                    482.1       1077.0   178.835399
# 4                  859.6                    762.3       1621.9   369.176621
#
#    iperf_stdDown  iperf_stdTotal
# 0     160.911328      341.710225
# 1     184.650090      273.639585
# 2     136.416234      236.250244
# 3      75.426859      231.176219
# 4     400.885146      720.323916

# %%
df_agg.drop(columns = ['instanceID','instanceID.1','setId'], inplace=True)

# %%
#group by tenants and take average
df = df_agg.groupby('tenants').mean()

# %%
df
# Out:
#          sysbench_wallTime  sysbench_std_wallTime  y_cruncher_wallTime  \
# tenants
# 1                 7.173863               0.002781             4.441481
# 31                      0.051021         150026.419358
# 32                      0.043809         149166.197913
# 33                      0.037062         143381.050506
# 34                      0.043986         137823.970597
# 35                      0.048685         137007.247623
# 36                      0.047003         136192.722228
# 37                      0.049197         135242.792792
# 38                      0.060314         132868.552634
# 39                      0.047048         132230.547013
# 40                      0.046359         131742.291672
# 41                      0.043434         131013.040656
# 42                      0.052979         128862.126983
# 43                      0.050796         128039.883723
# 44                      0.060284         127365.515148
# 45                      0.055232         126609.770371
# 46                      0.050155         124828.717396
# 47                      0.062639         123718.496457
# 48                      0.064182         123217.833340
#
#          pgbench_std_transactions  iperf_bandwidthUpload  \
# tenants
# 1                      520.497198            4970.000000
# 2                     1164.334396            4970.000000
# 3                      185.429822            4970.000000
# 4                      215.980395            4968.500000
# 5                      219.544020            4497.160000
# 6                      207.884763            3960.166667
# 7                      257.873714            3494.657143
# 8                      336.118945            3069.200000
# 9                      277.936759            2728.333333
# 10                     203.072808            2456.820000
# 11                     192.769852            2234.218182
# 12                     353.427462            2047.150000
# 13                     272.847628            1888.200000
# 14                     198.470274            1740.807143
# 15                     204.754227            1636.706667
# 16                     257.009931            1534.243750
# 17                     298.433124            1441.811765
# 18                     403.542371            1361.216667
# 19                     368.943369            1288.889474
# 20                     291.915269            1224.970000
# 21                     227.404746            1165.980952
# 22                     290.297782            1110.972727
# 23                     260.075476            1063.095652
# 24                     281.690828            1022.612500
# 25                     257.327560             977.332000
# 26                     261.513624             937.857692
# 27                     293.511088             903.288889
# 28                     315.133282             870.000000
# 29                     263.287025             839.572414
# 30                     235.256648             810.386667
# 31                     320.452217             784.570968
# 32                     232.638375             777.815625
# 33                     209.870432             769.939394
# 34                     260.202196             754.726471
# 35                     229.233019             753.137143
# 36                     245.380730             740.091667
# 37                     215.632087             726.740541
# 38                     248.635999             693.484211
# 39                     245.870492             685.951282
# 40                     214.673531             656.362500
# 41                     249.937181             650.053659
# 42                     219.433240             631.061905
# 43                     252.526836             614.713953
# 44                     273.613625             602.606818
# 45                     236.908800             590.184444
# 46                     275.580372             571.791304
# 47                     348.427707             567.453191
# 48                     493.228246             649.322917
#
#          iperf_bandwitdhDownload  iperf_total  iperf_stdUp  iperf_stdDown  \
# tenants
# 1                    4745.000000  9715.000000     0.000000     321.601893
# 2                    4882.000000  9852.000000     0.000000     121.203625
# 3                    4843.333333  9813.333333     0.000000     307.224503
# 4                    4849.000000  9817.500000     4.743416     253.151631
# 5                    3971.280000  8468.440000   432.897239    1016.849987
# 6                    3249.166667  7209.333333   372.127563     963.965824
# 7                    2942.985714  6437.642857   251.134147    1017.065421
# 8                    2629.812500  5699.012500   195.595563     921.195761
# 9                    2286.611111  5014.944444   347.525549     921.102136
# 10                   2203.730000  4660.550000   502.040293     795.855729
# 11                   1911.036364  4145.254545   448.370867     952.027320
# 45           408.386424
# 46           404.951753
# 47           396.310664
# 48           526.768760

# %%
sns.pairplot(df)
plt.show()

# %%
#heatmap of agg
plt.figure(figsize=(10,10))
sns.heatmap(df_agg.corr(), annot=True)
plt.show()

# %%
#tenants vs metric plot
data_plot = df[['sysbench_wallTime', 'y_cruncher_wallTime', 'pgbench_transactions', 'iperf_total']]
sns.lineplot(data=data_plot, palette="tab10", linewidth=2.5)
plt.show()

# %% [markdown]
# <h3>this graph doesn't tell us much. I think we need to normalize the data first</h3>

# %%
#we need to normalize the relevant columns
min_max_scaler = preprocessing.MinMaxScaler()
df_normalized = pd.DataFrame(min_max_scaler.fit_transform(df), columns=df.columns, index=df.index)

# %%
df_normalized.head()

# %%
#now with normalized df, let's try plotting again
data_plot = df_normalized[['sysbench_wallTime', 'y_cruncher_wallTime', 'pgbench_transactions', 'iperf_total']]

sns.lineplot(data=data_plot, palette="tab10", linewidth=2.5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# <h3>This normalized data looks great! Every experiment type besides iperf looks very linear, almost would be too easy for a ML algorithm to predict the tenancy...</h3>

# %% [markdown]
# <h2>Modeling</h2>

# %%
#do a random forest and/or linear regression on the 1176 data
df_agg.head()

# %%
#import ML dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

from sklearn import metrics

from sklearn.preprocessing import scale

from sklearn.datasets import load_wine
from sklearn.pipeline import make_pipeline

from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVR
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LinearRegression
from sklearn import linear_model

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# %%
#method to run simple model and outputs confusion matrix, calssification report, and f1-score
def get_model_result(X, y, model = LinearRegression(), test_size = 0.3):
    '''prints the confusion matrix and classification report and returns fitted model and X, y values'''
    
    X_train, X_test, y_train, y_test = train_test_split(X, 
                                                        y,
                                                        test_size = test_size,
                                                        random_state = 19,
                                                        #stratify = y
                                                      )

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    
    if (model == LinearRegression()):
        print('Coefficients: \n', model.coef_)
    elif (model == RandomForestRegressor()):
        print('Feature importances: \n',model.feature_importances_)
        
    # The mean squared error
    print("Mean squared error: %.2f" % mean_squared_error(y_test, y_pred))

    # Explained variance score: 1 is perfect prediction
    print('Variance score (r2 score): %.2f' % r2_score(y_test, y_pred))
    
    #return X_train, X_test, y_train, y_test, model

# %%
#method return x and y(setId) for models
def splitDfIntoXY(df, df_y_name):
    y = df[df_y_name].values
    x = df.drop(columns=[df_y_name])
    return x, y

# %%
#create x and y for model
x, y = splitDfIntoXY(df_agg, 'tenants')

# %%
#normalize x
x_normalized = pd.DataFrame(min_max_scaler.fit_transform(x), columns=x.columns, index=x.index)

# %%
x_normalized.head()

# %%
col = ['iperf_total', 'y_cruncher_wallTime', 'pgbench_transactions','sysbench_wallTime']

# %%
#use only the most relevant columns...
x_test = x_normalized[col]

# %%
#linear regression model
get_model_result(x_test,y, model = LinearRegression())

# %%
#random forest regression model
get_model_result(x_test,y, model = RandomForestRegressor())

# %% [markdown]
# <h2>Test on data from other dedicated host runs</h2>

# %%
print(os.listdir('./data/'))
