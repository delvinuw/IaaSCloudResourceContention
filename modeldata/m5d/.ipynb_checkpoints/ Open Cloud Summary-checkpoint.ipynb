# %%
#import dependencies 
from numpy.random import seed
from numpy.random import randn
from scipy import stats
import numpy as np

import math  

import seaborn as sns
sns.set(style="darkgrid")
from matplotlib import pyplot as plt

import pandas as pd
import os

# %%
#check list of files in data 
directory = "./data/dedicated_host/"
print(os.listdir(directory))
# Out:
# ['.DS_Store', 'm5d_pgbench_dedicated_host_11-16-2019.csv', 'm5d_y-cruncher_dedicated_host_11-16-2019_us-east-1 - Sheet1.csv', 'm5d_iperf_dedicated_host_11-17.csv', 'm5d_sysbench_dedicated_host_11-16-2019_us-east-1b - Sheet1.csv', 'newdata.csv']

# %%
#DON'T FORGET TO SET THIS!

#change experiment type and csv data...
experiment_type = 'sysbench'
data_name = 'm5d_sysbench_dedicated_host_11-16-2019_us-east-1b - Sheet1.csv'

#dedicated_host_mode = True

# %%
df_data = pd.read_csv(directory + data_name, header = 1);

# %%
df_data.head()
# Out:
#    experimentID           instanceID instanceType  wallTime  \
# 0  1573960552-0  i-0d6feb91baa545931    m5d.large  9.157414
# 1  1573960552-0  i-0d6feb91baa545931    m5d.large  9.038783
# 2  1573960552-0  i-0d6feb91baa545931    m5d.large  9.039020
# 3  1573960552-0  i-0d6feb91baa545931    m5d.large  9.041733
# 4  1573960552-0  i-0d6feb91baa545931    m5d.large  9.047082
#
#                                           testOption per-request-avg-time  \
# 0  --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.76ms
# 1  --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.40ms
# 2  --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.86ms
# 3  --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.86ms
# 4  --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.25ms
#
#   total-time  thread-num
# 0    9.0154s           2
# 1    9.0174s           2
# 2    9.0164s           2
# 3    9.0184s           2
# 4    9.0220s           2

# %%
#iperf remove trailing text
if (experiment_type == 'iperf'):
    df_data['bandwidthUpload'] = df_data['bandwidthUpload'].str.split(" ").str[0].astype('float64')
    df_data['bandwitdhDownload'] = df_data['bandwitdhDownload'].str.split(" ").str[0].astype('float64')
    #df_data.dropna(inplace = True)

# %%
df_data.tail()
# Out:
#         experimentID           instanceID instanceType  wallTime  \
# 23515  1573960552-23  i-07998976f194caa97    m5d.large  8.010195
# 23516  1573960552-23  i-07998976f194caa97    m5d.large  8.009076
# 23517  1573960552-23  i-07998976f194caa97    m5d.large  8.017726
# 23518  1573960552-23  i-07998976f194caa97    m5d.large  8.005946
# 23519  1573960552-23  i-07998976f194caa97    m5d.large  8.008423
#
#                                               testOption per-request-avg-time  \
# 23515  --test=cpu --cpu-max-prime=2000000 --num-threa...            1597.11ms
# 23516  --test=cpu --cpu-max-prime=2000000 --num-threa...            1596.62ms
# 23517  --test=cpu --cpu-max-prime=2000000 --num-threa...            1598.08ms
# 23518  --test=cpu --cpu-max-prime=2000000 --num-threa...            1596.45ms
# 23519  --test=cpu --cpu-max-prime=2000000 --num-threa...            1597.13ms
#
#       total-time  thread-num
# 23515    7.9879s           2
# 23516    7.9858s           2
# 23517    7.9976s           2
# 23518    7.9857s           2
# 23519    7.9881s           2

# %%
if (experiment_type == 'iperf'):
    #adjust gigbite values 'up' assuming all mbs values are over 100mb
    df_data['bandwitdhDownload'] = np.where(df_data['bandwitdhDownload'] > 100, df_data['bandwitdhDownload'], df_data['bandwitdhDownload']*1000)
    df_data['bandwidthUpload'] = np.where(df_data['bandwidthUpload'] > 100, df_data['bandwidthUpload'], df_data['bandwidthUpload']*1000)
    
    #add total bandwidth column
    df_data['total'] = df_data['bandwidthUpload'] + df_data['bandwitdhDownload']
    
    #sort by setId, vmId
    df_data = df_data.sort_values(by =['setId', 'vmId'], ascending = False)
    
    #reset index
    df_data.reset_index(drop=True, inplace= True)

# %%
#set nth column #change depending on data set...
if (experiment_type == 'iperf'):
    nth_column = 11
    if (not dedicated_host_mode):
        df_data = df_data[:551] #drop every run except first run
elif (experiment_type != 'pgbench'):
    nth_column = 10

# %%
#drop every nth column
#drop first row of each vm run since they are outliers (except pgbench)
if (experiment_type != 'pgbench'):
    df_data = df_data[df_data.index % nth_column != 0]

# %%
#check if correct columns are dropped..
df_data.head(14)
# Out:
#     experimentID           instanceID instanceType  wallTime  \
# 1   1573960552-0  i-0d6feb91baa545931    m5d.large  9.038783
# 2   1573960552-0  i-0d6feb91baa545931    m5d.large  9.039020
# 3   1573960552-0  i-0d6feb91baa545931    m5d.large  9.041733
# 4   1573960552-0  i-0d6feb91baa545931    m5d.large  9.047082
# 5   1573960552-0  i-0d6feb91baa545931    m5d.large  9.060294
# 6   1573960552-0  i-0d6feb91baa545931    m5d.large  9.040257
# 7   1573960552-0  i-0d6feb91baa545931    m5d.large  9.037618
# 8   1573960552-0  i-0d6feb91baa545931    m5d.large  9.043960
# 9   1573960552-0  i-0d6feb91baa545931    m5d.large  9.037151
# 11  1573960552-1  i-0d6feb91baa545931    m5d.large  9.049554
# 12  1573960552-1  i-0d6feb91baa545931    m5d.large  9.040604
# 13  1573960552-1  i-0d6feb91baa545931    m5d.large  9.043669
# 14  1573960552-1  i-0d6feb91baa545931    m5d.large  9.042775
# 15  1573960552-1  i-0d6feb91baa545931    m5d.large  9.065974
#
#                                            testOption per-request-avg-time  \
# 1   --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.40ms
# 2   --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.86ms
# 3   --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.86ms
# 4   --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.25ms
# 5   --test=cpu --cpu-max-prime=2000000 --num-threa...            1805.61ms
# 6   --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.73ms
# 7   --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.55ms
# 8   --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.43ms
# 9   --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.83ms
# 11  --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.42ms
# 12  --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.66ms
# 13  --test=cpu --cpu-max-prime=2000000 --num-threa...            1802.82ms
# 14  --test=cpu --cpu-max-prime=2000000 --num-threa...            1803.48ms
# 15  --test=cpu --cpu-max-prime=2000000 --num-threa...            1806.11ms
#
#    total-time  thread-num
# 1     9.0174s           2
# 2     9.0164s           2
# 3     9.0184s           2
# 4     9.0220s           2
# 5     9.0385s           2
# 6     9.0170s           2
# 7     9.0142s           2
# 8     9.0202s           2
# 9     9.0153s           2
# 11    9.0177s           2
# 12    9.0158s           2
# 13    9.0160s           2
# 14    9.0195s           2
# 15    9.0399s           2

# %%
#if in dedicated host mode, group by instanceID and 

#group by instanceID and take the mean of each column
df = df_data.groupby('instanceID').mean()

# %%
#convert setId index to column
df['setId'] = df.index.get_level_values(0)

# %%
#add tenancy info
#tenant_count = 48
#df['tenants'] = tenant_count - df['setId']

# %%
df.tail()
# Out:
#                      wallTime  thread-num                setId
# instanceID
# i-0dcfa6d3bc470d28d  8.264377           2  i-0dcfa6d3bc470d28d
# i-0e167bbfcd6a685f5  8.896894           2  i-0e167bbfcd6a685f5
# i-0ede59d8254436a40  8.889934           2  i-0ede59d8254436a40
# i-0f285214d5c41327e  8.270671           2  i-0f285214d5c41327e
# i-0f472084ac3992ad9  9.051273           2  i-0f472084ac3992ad9

# %%
#add standard deviation
df_std = df_data.groupby('experimentID').std()

# %%
df_std.head()

# %%
#add stds to main columns
if (experiment_type == 'iperf'):
    df['stdUp'] = df_std['bandwidthUpload']
    df['stdDown'] = df_std['bandwitdhDownload']
    df['stdTotal'] = df_std['total']
elif (experiment_type == 'y-cruncher'):
    df['std_computationTime'] = df_std['computationTime']
    df['std_benchmarkTime'] = df_std['benchmarkTime']
    df['std_wallTime'] = df_std['wallTime']
elif (experiment_type == 'sysbench'):
    df['std_wallTime'] = df_std['wallTime']
elif (experiment_type == 'pgbench'):
    df['std_wallTime'] = df_std['wallTime']
    df['std_transactions'] = df_std['transactions']
else:
    print('illegal benchmark name')

# %%
df.tail()

# %%
if (experiment_type == 'sysbench'):
    col = ['setId', 'tenants', 'wallTime', 'std_wallTime']
elif (experiment_type == 'iperf'):
    #df.drop(columns =['setId', 'experimentID'], inplace = True)
elif (experiment_type == 'pgbench'):
    #df.drop(columns =['clients', 'threads', 'scaleFactor'], inplace=True)

# %%
df = df[col]

# %%
df.tail()

# %%
df.describe()

# %%
#print to csv
df.to_csv(path_or_buf='./data/summary/dedicated_host/' + data_name + '-Summary.csv')

# %%
#graph the probablity of getting "better vm"
