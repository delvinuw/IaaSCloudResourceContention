# %%
#import dependencies 
from numpy.random import seed
from numpy.random import randn
from scipy import stats
import numpy as np

import math  

import seaborn as sns
sns.set(style="darkgrid")
from matplotlib import pyplot as plt

import pandas as pd
import os

# %%
#check list of files in data 
print(os.listdir("./data/open_cloud"))
# Out:
# ['.DS_Store', '50x_m5d_iperf_11-16-2019.csv', '50x_m5d_y-cruncher_open_cloud_11-16-2019.csv', '30x_m5d_11-14-2019', '50x_m5d_sysbench_open_cloud_11-16-2019-us-east-1b-2.csv', '50x_m5d_pgbench.csv']

# %%
data_name = '50x_m5d_y-cruncher_open_cloud_11-16-2019.csv'

# %%
df_data = pd.read_csv('./data/open_cloud/' + data_name);

# %%
df_data.count()
# Out:
# instanceID             500
# experimentID           500
# instanceType           500
# memoryInfo             500
# processorInfo          500
# sysTopology            500
# osVersion              500
# testStartTime          500
# availableMemory        500
# isMultiThread          500
# cpuUtilization         500
# multiCoreEfficiency    500
# computationTime        500
# benchmarkTime          500
# wallTime               500
# dtype: int64

# %%
#DON'T FORGET TO SET THIS!

#change experiment name depending on current csv data...
experiment_type = 'y-cruncher'

# %%
#iperf remove trailing text
if (experiment_type == 'iperf'):
    df_data['bandwidthUpload'] = df_data['bandwidthUpload'].str.split(" ").str[0].astype('float64')
    df_data['bandwitdhDownload'] = df_data['bandwitdhDownload'].str.split(" ").str[0].astype('float64')
    #df_data.dropna(inplace = True)

# %%
df_data.tail()
# Out:
#               instanceID  experimentID instanceType memoryInfo  \
# 495  i-0f83d46715e5b7ba9  1573942864-0    m5d.large   7.51 GiB
# 496  i-0f83d46715e5b7ba9  1573942864-0    m5d.large   7.51 GiB
# 497  i-0f83d46715e5b7ba9  1573942864-0    m5d.large   7.51 GiB
# 498  i-0f83d46715e5b7ba9  1573942864-0    m5d.large   7.51 GiB
# 499  i-0f83d46715e5b7ba9  1573942864-0    m5d.large   7.51 GiB
#
#                                      processorInfo  \
# 495  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 496  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 497  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 498  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 499  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
#
#                                      sysTopology  \
# 495  2 threads / 1 core / 1 socket / 1 NUMA node
# 496  2 threads / 1 core / 1 socket / 1 NUMA node
# 497  2 threads / 1 core / 1 socket / 1 NUMA node
# 498  2 threads / 1 core / 1 socket / 1 NUMA node
# 499  2 threads / 1 core / 1 socket / 1 NUMA node
#
#                               osVersion             testStartTime  \
# 495  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:28 2019
# 496  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:34 2019
# 497  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:39 2019
# 498  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:44 2019
# 499  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:49 2019
#
#     availableMemory isMultiThread cpuUtilization multiCoreEfficiency  \
# 495        7.19 GiB          Push       195.98 %             97.99 %
# 496        7.19 GiB          Push       197.09 %             98.55 %
# 497        7.19 GiB          Push       196.18 %             98.09 %
# 498        7.19 GiB          Push       196.18 %             98.09 %
# 499        7.19 GiB          Push       195.77 %             97.88 %
#
#      computationTime  benchmarkTime  wallTime
# 495            4.347          4.563  4.998482
# 496            4.363          4.587  5.024790
# 497            4.348          4.564  5.010003
# 498            4.373          4.595  5.032337
# 499            4.332          4.560  5.006716

# %%
df_data.describe()
# Out:
#        computationTime  benchmarkTime    wallTime
# count       500.000000     500.000000  500.000000
# mean          4.803890       5.020882    5.514916
# std           0.400771       0.410577    0.456463
# min           4.107000       4.271000    4.750742
# 25%           4.378750       4.674250    5.241357
# 50%           4.752500       4.953000    5.405596
# 75%           5.228000       5.456000    5.912690
# max           5.405000       5.875000    6.855086

# %%
if (experiment_type == 'iperf'):
    #adjust gigbite values 'up' assuming all mbs values are over 100mb
    df_data['bandwitdhDownload'] = np.where(df_data['bandwitdhDownload'] > 100, df_data['bandwitdhDownload'], df_data['bandwitdhDownload']*1000)
    df_data['bandwidthUpload'] = np.where(df_data['bandwidthUpload'] > 100, df_data['bandwidthUpload'], df_data['bandwidthUpload']*1000)
    
    #add total bandwidth column
    df_data['total'] = df_data['bandwidthUpload'] + df_data['bandwitdhDownload']
    
    #sort by setId, vmId
    df_data = df_data.sort_values(by =['setId', 'vmId'], ascending = False)
    
    #reset index
    df_data.reset_index(drop=True, inplace= True)

# %%
#set nth column #change depending on data set...
if (experiment_type != 'iperf'):
    nth_column = 11
    df_data = df_data[:551]
elif (experiment_type != 'pgbench'):
    nth_column = 10

# %%
#drop every nth column
#drop first row of each vm run since they are outliers (except pgbench)
if (experiment_type != 'pgbench'):
    df_data = df_data[df_data.index % nth_column != 0]

# %%
df_data.head()
# Out:
#             instanceID  experimentID instanceType memoryInfo  \
# 0  i-04b9c2f75a375d7e5  1573942864-0    m5d.large   7.51 GiB
# 1  i-04b9c2f75a375d7e5  1573942864-0    m5d.large   7.51 GiB
# 2  i-04b9c2f75a375d7e5  1573942864-0    m5d.large   7.51 GiB
# 3  i-04b9c2f75a375d7e5  1573942864-0    m5d.large   7.51 GiB
# 4  i-04b9c2f75a375d7e5  1573942864-0    m5d.large   7.51 GiB
#
#                                    processorInfo  \
# 0  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 1  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 2  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 3  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
# 4  Intel(R) Xeon(R) Platinum 8175M CPU @ 2.50GHz
#
#                                    sysTopology  \
# 0  2 threads / 1 core / 1 socket / 1 NUMA node
# 1  2 threads / 1 core / 1 socket / 1 NUMA node
# 2  2 threads / 1 core / 1 socket / 1 NUMA node
# 3  2 threads / 1 core / 1 socket / 1 NUMA node
# 4  2 threads / 1 core / 1 socket / 1 NUMA node
#
#                             osVersion             testStartTime  \
# 0  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:02 2019
# 1  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:07 2019
# 2  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:12 2019
# 3  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:17 2019
# 4  0.7.5.9480 (Linux/17-SKX ~ Kotori)  Sat Nov 16 22:23:22 2019
#
#   availableMemory isMultiThread cpuUtilization multiCoreEfficiency  \
# 0        7.19 GiB          Push       195.62 %             97.81 %
# 1        7.17 GiB          Push       196.76 %             98.38 %
# 2        7.19 GiB          Push       195.65 %             97.83 %
# 3        7.19 GiB          Push       196.48 %             98.24 %
# 4        7.19 GiB          Push       196.52 %             98.26 %
#
#    computationTime  benchmarkTime  wallTime
# 0            4.110          4.271  5.267560
# 1            4.117          4.381  4.823589
# 2            4.135          4.357  4.802282
# 3            4.117          4.364  4.807284
# 4            4.107          4.302  4.750742

# %%
#group by instanceID and take the mean of each column
df = df_data.groupby('instanceID').mean()

# %%
#groupby instanceID and take the standard deviation each column
df_std = df_data.groupby('instanceID').std()

# %%
df.head()
# Out:
#                      computationTime  benchmarkTime  wallTime
# instanceID
# i-0062d028d4b1b0c17           4.7504         4.9473  5.436827
# i-0069a2fb2881e526e           5.2300         5.4577  5.964130
# i-0096e0731defa5bcf           5.2486         5.4830  6.009766
# i-0098bacd16b57b4dc           4.1475         4.3605  4.885128
# i-00a374920f339188c           4.3578         4.5874  5.018877

# %%
#add stds to main columns
if (experiment_type == 'iperf'):
    df['stdUp'] = df_std['bandwidthUpload']
    df['stdDown'] = df_std['bandwitdhDownload']
    df['stdTotal'] = df_std['total']
elif (experiment_type == 'y-cruncher'):
    df['std_computationTime'] = df_std['computationTime']
    df['std_benchmarkTime'] = df_std['benchmarkTime']
    df['std_wallTime'] = df_std['wallTime']
else:
    print('illegal benchmark name')

# %%
df.tail()
# Out:
#                      experimentID  bandwidthUpload  bandwitdhDownload  setId  \
# instanceID
# i-0ece06eab633a3526    1573945123           9542.0             7086.0     50
# i-0f0e24c09425eac71    1573945123            744.0              800.9     50
# i-0f83d46715e5b7ba9    1573945123            751.4              736.3     50
# i-0fe52617ed49f921d    1573945123            744.5              794.3     50
# i-0ff32a7bce1e3a734    1573945123            751.7              742.9     50
#
#                      vmId    total      stdUp      stdDown     stdTotal
# instanceID
# i-0ece06eab633a3526    50  16628.0  88.166509  1105.724499  1155.958477
# i-0f0e24c09425eac71     5   1544.9   0.942809   191.349854   190.870782
# i-0f83d46715e5b7ba9    40   1487.7  22.016156    67.429057    71.411250
# i-0fe52617ed49f921d    22   1538.8   1.178511   356.556385   355.535840
# i-0ff32a7bce1e3a734    36   1494.6  23.664554    64.811607    55.634122

# %%
#if sysbench
#df.drop(columns =['thread-num'], inplace = True)

#if iperf
df.drop(columns =['setId', 'experimentID'], inplace = True)

# %%
df.head()
# Out:
#                      bandwidthUpload  bandwitdhDownload  vmId   total  \
# instanceID
# i-0062d028d4b1b0c17            744.3              790.4    15  1534.7
# i-0069a2fb2881e526e            744.2              791.8    11  1536.0
# i-0096e0731defa5bcf            751.7              743.1     3  1494.8
# i-0098bacd16b57b4dc            751.3              750.4    12  1501.7
# i-00a374920f339188c            744.3              812.9    37  1557.2
#
#                          stdUp     stdDown    stdTotal
# instanceID
# i-0062d028d4b1b0c17   0.674949  161.337603  160.810482
# i-0069a2fb2881e526e   1.135292  130.808427  130.312445
# i-0096e0731defa5bcf  25.069016   98.415728  100.874840
# i-0098bacd16b57b4dc  23.094251   77.660515   70.847332
# i-00a374920f339188c   0.674949  180.169951  179.711374

# %%
#print to csv
df.to_csv(path_or_buf='./data/summary/' + data_name + '-Summary.csv')

# %%
df.describe()
# Out:
#        bandwidthUpload  bandwitdhDownload      vmId         total  \
# count        48.000000          48.000000  50.00000     48.000000
# mean       1266.556250        1228.535417  25.50000   2495.091667
# std        1662.705596        1371.040017  14.57738   3025.180496
# min         743.600000         697.800000   1.00000   1450.300000
# 25%         744.200000         745.075000  13.25000   1496.600000
# 50%         744.600000         786.300000  25.50000   1530.350000
# 75%         751.625000         800.125000  37.75000   1544.225000
# max        9542.000000        7086.000000  50.00000  16628.000000
#
#              stdUp      stdDown     stdTotal
# count    48.000000    48.000000    48.000000
# mean     40.644170   236.492738   265.504095
# std     204.254104   292.456044   446.972014
# min       0.000000    10.637460    25.131653
# 25%       0.918937    99.386002    98.918718
# 50%       1.203892   161.155671   160.400748
# 75%      22.717588   197.425075   196.739021
# max    1422.238552  1428.753244  2833.419803

# %%
#graph the probablity of getting "better vm"
